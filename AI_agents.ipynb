# %% [markdown]
# <a href="https://colab.research.google.com/github/casualcomputer/datasets/blob/master/AI_agents.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # A. Thread Format Strategy

# %% [markdown]
# 1. json/html outputs
#
# 2. Concatenation with Delimiters: Joining comment texts into a single string using special characters or patterns to separate individual comments and indicate hierarchy.
#
# 3. Structured Input with Role/Hierarchy Indicators: Including explicit labels or markers within the text to denote the role of each turn (e.g., "Comment", "Reply") and its position in the conversation tree (e.g., "Level 0", "Level 1").
#
# 4. Summarization or Extraction before Feeding: Pre-processing the conversation to create summaries of threads or extract key information, reducing the input size for the LLM.
#
# 5. Feeding in Chunks: Breaking down very long conversations into smaller segments to fit within the LLM's context window, potentially processing each chunk separately.
#
# 6. Using Models Designed for Conversational Data: Utilizing LLMs specifically trained to handle conversational turns and maintain context across interactions.

# %% [markdown]
# ## A1. Json outputs

# %%
import requests

item_id = 44047693
url = f"https://hn.algolia.com/api/v1/items/{item_id}"
response = requests.get(url)
data = response.json()

data
# Out:
# {'author': 'bookofjoe',
#  'children': [{'author': 'bookofjoe',
#    'children': [],
#    'created_at': '2025-05-21T02:13:59.000Z',
#    'created_at_i': 1747793639,
#    'id': 44047694,
#    'options': [],
#    'parent_id': 44047693,
#    'points': None,
#    'story_id': 44047693,
#    'text': '<a href="https:&#x2F;&#x2F;archive.ph&#x2F;1geSw" rel="nofollow">https:&#x2F;&#x2F;archive.ph&#x2F;1geSw</a>',
#    'title': None,
#    'type': 'comment',
#    'url': None},
#   {'author': 'neom',
#    'children': [],
#    'created_at': '2025-05-21T02:49:10.000Z',
#    'created_at_i': 1747795750,
#    'id': 44047849,
#    'options': [],
#    'parent_id': 44047693,
#    'points': None,
#    'story_id': 44047693,
#    'text': 'The owner is the grandson of the Ziff Davis fortune. <a href="https:&#x2F;&#x2F;en.wikipedia.org&#x2F;wiki&#x2F;Ziff_Davis" rel="nofollow">https:&#x2F;&#x2F;en.wikipedia.org&#x2F;wiki&#x2F;Ziff_Davis</a> (Popular Electronics, PC Mag, ZDNET, etc.)',
#    'title': None,
#    'type': 'comment',
#    'url': None},
#   {'author': 'WorkerBee28474',
#    'children': [],
#    'created_at': '2025-05-21T03:01:31.000Z',
#    'created_at_i': 1747796491,
#    'id': 44047894,
#    'options': [],
#    'parent_id': 44047693,
#    'points': None,
#    'story_id': 44047693,
#    'text': '&gt; In the spring of 2027, the museum will open a permanent gallery devoted to the evolution and cultural impact of the American guitar.<p>This is fun, it looks like they have many important prototype and early production guitars.',
#    'title': None,
#    'type': 'comment',
#    'url': None}],
#  'created_at': '2025-05-21T02:13:50.000Z',
#  'created_at_i': 1747793630,
#  'id': 44047693,
#  'options': [],
#  'parent_id': None,
#  'points': 40,
#  'story_id': 44047693,
#  'text': None,
#  'title': 'A Secret Trove of Rare Guitars Heads to the Met',
#  'type': 'story',
#  'url': 'https://www.newyorker.com/magazine/2025/05/26/a-secret-trove-of-rare-guitars-heads-to-the-met'}

# %% [markdown]
# ## A2. Recursive Concatenation

# %%
import requests

item_id = 44047693
url = f"https://hn.algolia.com/api/v1/items/{item_id}"
response = requests.get(url)
data = response.json()
print("data['children']: " ,data['children'])

conversation_text = ""

# Function to recursively build the conversation string
def build_conversation_string(item, indent=0):
    global conversation_text # Use the global variable

    if 'text' in item and item['text'] is not None:
        # Add indentation and the comment text
        conversation_text += "  " * indent + item['text'] + "\n\n" # Add newlines

    # Check if the item has children (replies)
    if 'children' in item and item['children']:
        # If it has children, recursively call the function for each child
        for child in item['children']:
            build_conversation_string(child, indent + 1) # Increase indent

# Start building the conversation string with the main item's children
if 'children' in data and data['children']:
    for top_level_comment in data['children']:
        build_conversation_string(top_level_comment, indent=0)

# The 'conversation_text' variable now holds the concatenated conversation
print(conversation_text)

# Now you can feed 'conversation_text' to your LLM
# Example (conceptual):
# llm_input = {"prompt": "Summarize the following conversation:\n" + conversation_text}
# llm_output = your_llm_api_call(llm_input)
# Out:
# data['children']:  [{'author': 'bookofjoe', 'children': [], 'created_at': '2025-05-21T02:13:59.000Z', 'created_at_i': 1747793639, 'id': 44047694, 'options': [], 'parent_id': 44047693, 'points': None, 'story_id': 44047693, 'text': '<a href="https:&#x2F;&#x2F;archive.ph&#x2F;1geSw" rel="nofollow">https:&#x2F;&#x2F;archive.ph&#x2F;1geSw</a>', 'title': None, 'type': 'comment', 'url': None}, {'author': 'neom', 'children': [], 'created_at': '2025-05-21T02:49:10.000Z', 'created_at_i': 1747795750, 'id': 44047849, 'options': [], 'parent_id': 44047693, 'points': None, 'story_id': 44047693, 'text': 'The owner is the grandson of the Ziff Davis fortune. <a href="https:&#x2F;&#x2F;en.wikipedia.org&#x2F;wiki&#x2F;Ziff_Davis" rel="nofollow">https:&#x2F;&#x2F;en.wikipedia.org&#x2F;wiki&#x2F;Ziff_Davis</a> (Popular Electronics, PC Mag, ZDNET, etc.)', 'title': None, 'type': 'comment', 'url': None}, {'author': 'WorkerBee28474', 'children': [], 'created_at': '2025-05-21T03:01:31.000Z', 'created_at_i': 1747796491, 'id': 44047894, 'options': [], 'parent_id': 44047693, 'points': None, 'story_id': 44047693, 'text': '&gt; In the spring of 2027, the museum will open a permanent gallery devoted to the evolution and cultural impact of the American guitar.<p>This is fun, it looks like they have many important prototype and early production guitars.', 'title': None, 'type': 'comment', 'url': None}]
# <a href="https:&#x2F;&#x2F;archive.ph&#x2F;1geSw" rel="nofollow">https:&#x2F;&#x2F;archive.ph&#x2F;1geSw</a>
#
# The owner is the grandson of the Ziff Davis fortune. <a href="https:&#x2F;&#x2F;en.wikipedia.org&#x2F;wiki&#x2F;Ziff_Davis" rel="nofollow">https:&#x2F;&#x2F;en.wikipedia.org&#x2F;wiki&#x2F;Ziff_Davis</a> (Popular Electronics, PC Mag, ZDNET, etc.)
#
# &gt; In the spring of 2027, the museum will open a permanent gallery devoted to the evolution and cultural impact of the American guitar.<p>This is fun, it looks like they have many important prototype and early production guitars.

# %%
item_id = 44047693
url = f"https://hn.algolia.com/api/v1/items/{item_id}"
response = requests.get(url)
data = response.json()

comments = data['children']
for comment in comments:
  print(comment['text'])
  print('\n')
# Out:
# <a href="https:&#x2F;&#x2F;archive.ph&#x2F;1geSw" rel="nofollow">https:&#x2F;&#x2F;archive.ph&#x2F;1geSw</a>
#
#
# The owner is the grandson of the Ziff Davis fortune. <a href="https:&#x2F;&#x2F;en.wikipedia.org&#x2F;wiki&#x2F;Ziff_Davis" rel="nofollow">https:&#x2F;&#x2F;en.wikipedia.org&#x2F;wiki&#x2F;Ziff_Davis</a> (Popular Electronics, PC Mag, ZDNET, etc.)
#
#
# &gt; In the spring of 2027, the museum will open a permanent gallery devoted to the evolution and cultural impact of the American guitar.<p>This is fun, it looks like they have many important prototype and early production guitars.

# %% [markdown]
# # Dataset for AI agent

# %%
import requests
import pandas as pd

# Load the JSON from GitHub
url = "https://raw.githubusercontent.com/casualcomputer/datasets/master/conversations.json"
data = requests.get(url).json()

# Normalize into a DataFrame
conversation_df = pd.json_normalize(data["conversations"])
conversation_df
# Out:
#       item_id                                  conversation_text
# 0    39765630  I like the interactive setup. I think this is ...
# 1    39763458  I am fascinated they used 60 pounds and a larg...
# 2    39761650  I’ve seen this at a Fortune-50 company, on the...
# 3    39771596  ESG was basically instantly exploited to the p...
# 4    39764387  Paywall-free: <a href="https:&#x2F;&#x2F;archi...
# ..        ...                                                ...
# 250  39768860  A friend of mine from a farming family in Euro...
# 251  39768434  <a href="https:&#x2F;&#x2F;www.flightradar24.c...
# 252  39770249  qacom for radio company? was mokia taken?\n\n ...
# 253  39748761  And of course the Nick Metropolis mentioned in...
# 254  39752026  <a href="https:&#x2F;&#x2F;archive.ph&#x2F;W2l...
#
# [255 rows x 2 columns]

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/casualcomputer/datasets/master/analysis_results.csv"

threads_summary = pd.read_csv(url).sort_values(by='rank', ascending=False)
threads_summary
# Out:
#       rank                                              title  \
# 10   255.0  Biden is giving Intel $8.5B for big semiconduc...
# 11   254.0  How does perception of climate protest influen...
# 12   253.0  US Weighs Sanctioning Huawei's Secretive Chine...
# 13   252.0  Researchers demonstrate breakthrough recyclabi...
# 14   251.0  Intel receives $8.5B from US for expanding hig...
# ..     ...                                                ...
# 247    5.0  Michel Talagrand wins Abel Prize for work wran...
# 248    4.0                          Google Scholar PDF Reader
# 249    3.0  Rive Renderer for real-time vector graphics is...
# 250    2.0                  Suspicious discontinuities (2020)
# 251    1.0                Flightradar24's new GPS jamming map
#
#                                                   link   item_id  page  \
# 10                     https://text.npr.org/1239533039  39768240     9
# 11   https://www.nature.com/articles/s44168-023-000...  39769918     9
# 12   https://www.bloomberg.com/news/articles/2024-0...  39769909     9
# 13   https://phys.org/news/2024-03-breakthrough-rec...  39762164     9
# 14   https://arstechnica.com/tech-policy/2024/03/in...  39766518     9
# ..                                                 ...       ...   ...
# 247  https://www.quantamagazine.org/michel-talagran...  39764954     1
# 248  https://scholar.googleblog.com/2024/03/superch...  39768438     1
# 249  https://rive.app/blog/rive-renderer-now-open-s...  39766893     1
# 250                https://danluu.com/discontinuities/  39768860     1
# 251  https://www.flightradar24.com/blog/gps-jamming...  39768434     1
#
#                     scrape_time  \
# 10   2025-05-17 11:28:26.188898
# 11   2025-05-17 11:28:26.187889
# 12   2025-05-17 11:28:26.187889
# 13   2025-05-17 11:28:26.187889
# 14   2025-05-17 11:28:26.186382
# ..                          ...
# 247  2025-05-17 11:28:00.178128
# 248  2025-05-17 11:28:00.178128
# 249  2025-05-17 11:28:00.176560
# 250  2025-05-17 11:28:00.176560
# 251  2025-05-17 11:28:00.176560
#
#                                          content_saved
# 10                                                 NaN
# 11   D:\alpha_seeker\content_2024-03-20\1178aeb149c...
# 12                                                 NaN
# 13   D:\alpha_seeker\content_2024-03-20\19037b0b087...
# 14   D:\alpha_seeker\content_2024-03-20\e21d0bea450...
# ..                                                 ...
# 247  D:\alpha_seeker\content_2024-03-20\a3b498a5018...
# 248  D:\alpha_seeker\content_2024-03-20\98fd21dea64...
# 249  D:\alpha_seeker\content_2024-03-20\938c76f3e1d...
# 250  D:\alpha_seeker\content_2024-03-20\2779493d1bf...
# 251  D:\alpha_seeker\content_2024-03-20\32d2683cf43...
#
# [255 rows x 7 columns]

# %%
# Perform a left merge of threads_summary and conversation_df on the 'item_id' column
conversation_df['item_id'] = pd.to_numeric(conversation_df['item_id'], errors='coerce').astype('Int64')

# Now perform the left merge
merged_df = threads_summary.merge(conversation_df, on='item_id', how='left').sort_values(by='rank')

# Display the first few rows of the merged DataFrame
merged_df.head()
# Out:
#      rank                                              title  \
# 254   1.0                Flightradar24's new GPS jamming map
# 253   2.0                  Suspicious discontinuities (2020)
# 252   3.0  Rive Renderer for real-time vector graphics is...
# 251   4.0                          Google Scholar PDF Reader
# 250   5.0  Michel Talagrand wins Abel Prize for work wran...
#
#                                                   link   item_id  page  \
# 254  https://www.flightradar24.com/blog/gps-jamming...  39768434     1
# 253                https://danluu.com/discontinuities/  39768860     1
# 252  https://rive.app/blog/rive-renderer-now-open-s...  39766893     1
# 251  https://scholar.googleblog.com/2024/03/superch...  39768438     1
# 250  https://www.quantamagazine.org/michel-talagran...  39764954     1
#
#                     scrape_time  \
# 254  2025-05-17 11:28:00.176560
# 253  2025-05-17 11:28:00.176560
# 252  2025-05-17 11:28:00.176560
# 251  2025-05-17 11:28:00.178128
# 250  2025-05-17 11:28:00.178128
#
#                                          content_saved  \
# 254  D:\alpha_seeker\content_2024-03-20\32d2683cf43...
# 253  D:\alpha_seeker\content_2024-03-20\2779493d1bf...
# 252  D:\alpha_seeker\content_2024-03-20\938c76f3e1d...
# 251  D:\alpha_seeker\content_2024-03-20\98fd21dea64...
# 250  D:\alpha_seeker\content_2024-03-20\a3b498a5018...
#
#                                      conversation_text
# 254  <a href="https:&#x2F;&#x2F;www.flightradar24.c...
# 253  A friend of mine from a farming family in Euro...
# 252  Repo: <a href="https:&#x2F;&#x2F;github.com&#x...
# 251  That&#x27;s nice and all, but google scholar r...
# 250  Following Shaw Price in 2019 <a href="https:&#...

# %% [markdown]
# # AI agents

# %%
# !pip install crewai --quiet

# %%
# Start your codes
